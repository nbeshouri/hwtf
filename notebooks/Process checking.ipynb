# %%
path = '/Users/nbeshouri/Documents/Projects/Metis/Project 4/hwmf/data/character_bios_tokenized.pickle'

# %%
import joblib
import re
title_to_article = joblib.load(path)

# %%
for sent in title_to_article['Kraven the Hunter']:
    print(sent)
    print()
# Out:
# <SUBJECT> the <ENITY> is a fictional supervillain appearing in <ENITY> comic books published by <ENITY> .
#
# in <ENITY> , <SUBJECT> was ranked as <ENITY> 's <ENITY> of all <ENITY> .
#
# the <SUBJECT> being of <ENITY> most long-standing archenemies .
#
# while the real <SUBJECT> ambushes the hero .
#
# however , despite <SUBJECT> having weakened <ENITY> with a poisonous dart .
#
# because <SUBJECT> continually underestimates the superhero 's resourcefulness .
#
# <SUBJECT> becomes a founding member of the <ENITY> when <SUBJECT> accepts <ENITY> ' offer to form a team to fight <ENITY> where <SUBJECT> capture <ENITY> and <ENITY> .
#
# after <ENITY> and <ENITY> are rescued , <SUBJECT> the <ENITY> and the rest of the <ENITY> are arrested by the police .
#
# while in the <ENITY> , <SUBJECT> the <ENITY> found <ENITY> in a spaceship <SUBJECT> stumbles that upon .
#
# realizing how useful <ENITY> can be , <SUBJECT> the <SUBJECT> decides to use him in a plot to conquer the <ENITY> .
#
# ...

# %%
path = '/Users/nbeshouri/Documents/Projects/Metis/Project 4/hwmf/data/character_bios_tokenized.pickle'
tokenized = joblib.load(path)
path = '/Users/nbeshouri/Documents/Projects/Metis/Project 4/hwmf/data/character_bios_lemmatized.pickle'
lemmatized = joblib.load(path)

# %%
for sent in lemmatized['C-3PO']:
    print(sent)
    print()
# Out:
# rebuild <ENITY> <SUBJECT> design protocol droid intend assist etiquette custom translation boast <SUBJECT> fluent form communication
#
# along astromech droid counterpart friend <ENITY> <SUBJECT> provide comic relief narrative structure film serve foil
#
# despite oblivious nature <SUBJECT> play pivotal role <ENITY>'s history appear service <ENITY> <ENITY> homestead <ENITY> <ENITY> <ENITY> <ENITY>
#
# <SUBJECT> appear frequently canon <ENITY> continuity novel comic book video game protagonist <ENITY> television <ENITY>
#
# in <ENITY> <SUBJECT> introduce audience <SUBJECT> <ENITY> aboard consular ship <ENITY> <SUBJECT> attack <ENITY>
#
# when <ENITY> attempt leave ship deliver secret message <ENITY> <SUBJECT> follow <ENITY> escape pod land planet <ENITY>
#
# in process sell <ENITY> <SUBJECT> convince new owner buy <ENITY>
#
# when ship take hostage <ENITY> <SUBJECT> help <ENITY> shut space station's trash computer save human companion life escape board <ENITY>
#
# ...

# %%
for sent in title_to_article['Harry Kim (Star Trek)']:
    print(sent)
    print()
# Out:
# <SUBJECT> is a fictional character who appeared in each of <ENITY> of the <ENITY> television series <ENITY> : <ENITY> .
#
# that <SUBJECT> represented <ENITY> of the elements of multiculturalism in the crew of <ENITY> , which also represented a proxy family for <ENITY> .
#
# <SUBJECT> difficult as there was n't a great number of young <ENITY> actors to choose from .
#
# as <SUBJECT> would need to fight to stay in the forefront of episodes .
#
# <SUBJECT> was born in <ENITY> .
#
# <SUBJECT> immediately became friends with <ENITY> after <SUBJECT> was assigned to the vessel for the mission which saw <ENITY> sent to track down a <ENITY> vessel in the <ENITY> .
#
# where <SUBJECT> and <ENITY> are abducted to an <ENITY> medical facility .
#
# at the time of the stranding of the ship , <SUBJECT> was engaged to be married , but <ENITY> was encouraged to date other crew members by <ENITY> .
#
# ...
