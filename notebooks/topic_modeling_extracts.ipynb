# %%
cd ~/Dropbox/project_4
# Out:
# /Users/nbeshouri/Documents/Projects/Metis/Project 4

# %%
from hwmf import utils, data, models
import re
import gensim
from gensim.models import doc2vec
from gensim import corpora, similarities, matutils
from sklearn.feature_extraction.text import CountVectorizer

# %%
name_to_article = utils.load_data('character_extracts_lemmatized.pickle')

# %%
import logging
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.INFO, filename='logs/lda_extracts.txt')
# logging.basicConfig(level=logging.INFO)

# %%
model_1, count_vec_2, index_2 = models.train_lda_model(name_to_article, num_topics=15, workers=4, passes=400, save_name='lda_extracts.pickle')
# Out:
# Process ForkPoolWorker-15:
# KeyboardInterrupt
# Process ForkPoolWorker-16:
# Process ForkPoolWorker-14:
# Process ForkPoolWorker-13:
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/Users/nbeshouri/anaconda/envs/aind/lib/python3.6/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/Users/nbeshouri/anaconda/envs/aind/lib/python3.6/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
#   File "/Users/nbeshouri/anaconda/envs/aind/lib/python3.6/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
#   File "/Users/nbeshouri/anaconda/envs/aind/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/nbeshouri/anaconda/envs/aind/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/nbeshouri/anaconda/envs/aind/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/nbeshouri/anaconda/envs/aind/lib/python3.6/multiprocessing/pool.py", line 103, in worker
#     initializer(*initargs)
#   File "/Users/nbeshouri/anaconda/envs/aind/lib/python3.6/multiprocessing/pool.py", line 103, in worker
#     initializer(*initargs)
#   File "/Users/nbeshouri/anaconda/envs/aind/lib/python3.6/multiprocessing/pool.py", line 103, in worker
#     initializer(*initargs)
#   File "/Users/nbeshouri/anaconda/envs/aind/lib/python3.6/site-packages/gensim/models/ldamulticore.py", line 286, in worker_e_step
#     chunk_no, chunk, worker_lda = input_queue.get()
# Traceback (most recent call last):
#   File "/Users/nbeshouri/anaconda/envs/aind/lib/python3.6/multiprocessing/queues.py", line 93, in get
#     with self._rlock:
#   File "/Users/nbeshouri/anaconda/envs/aind/lib/python3.6/site-packages/gensim/models/ldamulticore.py", line 286, in worker_e_step
#     chunk_no, chunk, worker_lda = input_queue.get()
#   File "/Users/nbeshouri/anaconda/envs/aind/lib/python3.6/site-packages/gensim/models/ldamulticore.py", line 286, in worker_e_step
#     chunk_no, chunk, worker_lda = input_queue.get()
#   File "/Users/nbeshouri/anaconda/envs/aind/lib/python3.6/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
#   File "/Users/nbeshouri/anaconda/envs/aind/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/nbeshouri/anaconda/envs/aind/lib/python3.6/multiprocessing/queues.py", line 93, in get
#     with self._rlock:
#   File "/Users/nbeshouri/anaconda/envs/aind/lib/python3.6/multiprocessing/synchronize.py", line 96, in __enter__
#     return self._semlock.__enter__()
#   File "/Users/nbeshouri/anaconda/envs/aind/lib/python3.6/multiprocessing/queues.py", line 93, in get
#     with self._rlock:
# KeyboardInterrupt
#   File "/Users/nbeshouri/anaconda/envs/aind/lib/python3.6/multiprocessing/synchronize.py", line 96, in __enter__
#     return self._semlock.__enter__()
#   File "/Users/nbeshouri/anaconda/envs/aind/lib/python3.6/multiprocessing/pool.py", line 103, in worker
#     initializer(*initargs)
#   File "/Users/nbeshouri/anaconda/envs/aind/lib/python3.6/multiprocessing/synchronize.py", line 96, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/Users/nbeshouri/anaconda/envs/aind/lib/python3.6/site-packages/gensim/models/ldamulticore.py", line 286, in worker_e_step
#     chunk_no, chunk, worker_lda = input_queue.get()
#   File "/Users/nbeshouri/anaconda/envs/aind/lib/python3.6/multiprocessing/queues.py", line 94, in get
#     res = self._recv_bytes()
#   File "/Users/nbeshouri/anaconda/envs/aind/lib/python3.6/multiprocessing/connection.py", line 216, in recv_bytes
#     buf = self._recv_bytes(maxlength)
#   File "/Users/nbeshouri/anaconda/envs/aind/lib/python3.6/multiprocessing/connection.py", line 407, in _recv_bytes
#     buf = self._recv(4)
#   File "/Users/nbeshouri/anaconda/envs/aind/lib/python3.6/multiprocessing/connection.py", line 379, in _recv
#     chunk = read(handle, remaining)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-4395f604dddc> in <module>()
# ----> 1 model_1, count_vec_2, index_2 = models.train_lda_model(name_to_article, num_topics=15, workers=4, passes=400, save_name='lda_extracts.pickle')
#
# ~/Documents/Projects/Metis/Project 4/hwmf/models.py in train_lda_model(name_to_article, num_topics, passes, workers, save_name)
#      43     names, articles = tuple(zip(*name_to_article.items()))
#      44     count_vectorizer = CountVectorizer(ngram_range=(1, 2))
# ---> 45     counts = count_vectorizer.fit_transform(articles)
#      46     counts = counts.transpose()
#      47     corpus = matutils.Sparse2Corpus(counts)
#
# ~/anaconda/envs/aind/lib/python3.6/site-packages/gensim/models/ldamulticore.py in __init__(self, corpus, num_topics, id2word, workers, chunksize, passes, batch, alpha, eta, decay, offset, eval_every, iterations, gamma_threshold, random_state, minimum_probability, minimum_phi_value, per_word_topics, dtype)
#     151             decay=decay, offset=offset, eval_every=eval_every, iterations=iterations,
#     152             gamma_threshold=gamma_threshold, random_state=random_state, minimum_probability=minimum_probability,
# --> 153             minimum_phi_value=minimum_phi_value, per_word_topics=per_word_topics, dtype=dtype
#     154         )
#     155
#
# ~/anaconda/envs/aind/lib/python3.6/site-packages/gensim/models/ldamodel.py in __init__(self, corpus, num_topics, id2word, distributed, chunksize, passes, update_every, alpha, eta, decay, offset, eval_every, iterations, gamma_threshold, minimum_probability, random_state, ns_conf, minimum_phi_value, per_word_topics, callbacks, dtype)
#     369         if corpus is not None:
#     370             use_numpy = self.dispatcher is not None
# --> 371             self.update(corpus, chunks_as_numpy=use_numpy)
#     372
#     373     def init_dir_prior(self, prior, name):
#
# ~/anaconda/envs/aind/lib/python3.6/site-packages/gensim/models/ldamulticore.py in update(self, corpus, chunks_as_numpy)
#     266             # wait for all outstanding jobs to finish
#     267             while queue_size[0] > 0:
# --> 268                 process_result_queue(force=True)
#     269
#     270             if reallen != lencorpus:
#
# ~/anaconda/envs/aind/lib/python3.6/site-packages/gensim/models/ldamulticore.py in process_result_queue(force)
#     228                 """
#     229                 merged_new = False
# --> 230                 while not result_queue.empty():
#     231                     other.merge(result_queue.get())
#     232                     queue_size[0] -= 1
#
# ~/anaconda/envs/aind/lib/python3.6/multiprocessing/queues.py in empty(self)
#     118
#     119     def empty(self):
# --> 120         return not self._poll()
#     121
#     122     def full(self):
#
# ~/anaconda/envs/aind/lib/python3.6/multiprocessing/connection.py in poll(self, timeout)
#     255         self._check_closed()
#     256         self._check_readable()
# --> 257         return self._poll(timeout)
#     258
#     259     def __enter__(self):
#
# ~/anaconda/envs/aind/lib/python3.6/multiprocessing/connection.py in _poll(self, timeout)
#     412
#     413     def _poll(self, timeout):
# --> 414         r = wait([self], timeout)
#     415         return bool(r)
#     416
#
# ~/anaconda/envs/aind/lib/python3.6/multiprocessing/connection.py in wait(object_list, timeout)
#     914                 else:
#     915                     if timeout is not None:
# --> 916                         timeout = deadline - time.time()
#     917                         if timeout < 0:
#     918                             return ready
#
# KeyboardInterrupt:

# %%
names, articles = list(zip(*name_to_article.items()))[0]

# %%
list(zip(*name_to_article.items()))[1][0]
# Out:
# 'in hero central great warrior mother immortal father mortal king notable feat slaying hero outside gate although death present source concur kill near end shoot heel arrow later legend begin poem state invulnerable body heel mother dip river infant hold heel allude legend term heel come mean point weakness especially strong constitution tablet attest personal form ki u ki dative turn female form attest form stele female gladiator fight analyze combination distress pain sorrow grief people soldier nation result proto form people distress people distress the grief distress people theme raise numerous time frequently role hero grief distress form ironic juxtaposition conventional view hero glory usually war furthermore construe follow mean corps soldier muster some topical epitheta point swift footedness swift footed divine frequently quick footed some researcher deem loan word possibly language suggest origin base thing coexistence epic language account palatalized phoneme /ly/ original language son king rival hand fore thinker warn prophecy originally utter goddess divine law bear son great father for reason god withdraw pursuit would there tale offer alternative version event in sister wife allude chaste resistance advance point loyal marriage bond coolly reject father god daughter sea god bring explain resistance advance furious decree marry immortal accord write non survive previous source bear try immortal dip river however leave vulnerable body hold left heel heel tendon clear version event know earlier in version anoint boy ambrosia fire burn away mortal part body interrupt abandon father son rage however source make reference general invulnerability to contrary mention wound hero son challenge river spear graze elbow draw spurt blood also fragmentary poem find description hero death i.e. little trace reference general invulnerability famous weakness heel later vase painting present death arrow case arrow hit body entrust rear foretell son fate gain glory die young live long uneventful life obscurity choose decide war accord grow companion some post homeric source claim order safe war version hide young man court king there disguise girl life daughter red haired girl with daughter account rap father son call father possible alias accord learn prophet unable capture aid go guise peddler sell woman clothe jewelry place shield spear good when instantly take spear see disguise convince join campaign in version arrange trumpet alarm sound woman woman flee panic prepare defend court give identity away accord arrive ship carry appoint leader leader command when leave accidentally stop rule in result battle give wound heal consult oracle state wound shall heal guide oracle arrive heal order guide voyage accord report lost play go pretend beggar ask heal wound refuse claim medical knowledge alternatively hold ransom ransom aid heal wound reason spear inflict wound spear able heal piece spear scrap wound heal however romance describe medieval invention summary transmit medieval old account young prince young legitimate son accord source son despite youth main war leader horse fighter chariot fighter accord link fate ambush attempt capture yet strike beauty sister overcome lust direct sexual attention refuse yield instead find decapitate altar omphalos later version suggest accidentally kill ardent lover embrace in version myth death come retribution sacrilege ancient writer treat epitome dead child mourn parent have live adulthood claim invincible famous narrative deed wrath central theme poem the line read the epic cover war narrate death begin withdrawal battle dishonour commander force take woman name slave father priest beg return refuse send plague the prophet correctly determine source trouble speak vow protect declare return father consent command battle prize daughter bring replace angry dishonour have plunder glory take away say later love urging mother refuse fight lead troop alongside force at time burn rage theft pray  ...

# %%
names = []
articles = []
for name, article in name_to_article.items():
    names.append(name)
    articles.append(article)

# %%
title_black_list = utils.load_values('character_article_title_black_list.csv')
word_black_list = utils.load_values('character_article_word_black_list.csv')

def remove_black_listed(doc_string):
    black_list = sorted(word_black_list, key=lambda x: -len(x))
    patterns = []
    for pattern in word_black_list:
        patterns.append(r'\b' + pattern + '\b')
    patterns += word_black_list
    for pattern in patterns:
        doc_string = re.sub(pattern, '', doc_string)
    return doc_string

def to_word_list(sents):
    merged = merge_sents(sents)
    merged = remove_black_listed(merged)
    return gensim.utils.simple_preprocess(merged)


count_vectorizer = CountVectorizer(ngram_range=(1, 2),  
                                   stop_words='english', token_pattern="\\b[a-z][a-z]+\\b")
counts = count_vectorizer.fit_transform(articles)
counts = counts.transpose()
corpus = matutils.Sparse2Corpus(counts)

# %%
id2word = dict((v, k) for k, v in count_vectorizer.vocabulary_.items())
lda = models.LdaMulticore(corpus=corpus, num_topics=20, minimum_probability=0.03, id2word=id2word, passes=10, workers=8)

# %%
count_vectorizer[]

# %%
lda.id2word
# Out:
# {1811478: 'greek',
#  2834832: 'mythology',
#  31289: 'achilles',
#  31730: 'achilleus',
#  103193: 'akhilleus',
#  1935822: 'hero',
#  4337983: 'trojan',
#  4531190: 'war',
#  673310: 'central',
#  694003: 'character',
#  1810122: 'greatest',
#  4540772: 'warrior',
#  1975703: 'homer',
#  2042389: 'iliad',
#  2792568: 'mother',
#  2051770: 'immortal',
#  2877894: 'nereid',
#  4213246: 'thetis',
#  1510849: 'father',
#  2790614: 'mortal',
#  3081446: 'peleus',
#  2308252: 'king',
#  2830890: 'myrmidons',
#  2913625: 'notable',
#  1523596: 'feat',
#  3867536: 'slaying',
#  1911561: 'hector',
#  3011085: 'outside',
#  1715656: 'gates',
#  4341456: 'troy',
#  1051043: 'death',
#  3232705: 'presented',
#  3919537: 'sources',
#  857705: 'concur',
#  2294254: 'killed',
#  2862302: 'near',
#  1350460: 'end',
#  3046910: 'paris',
#  3806520: 'shot',
#  1912451: 'heel',
#  244701: 'arrow',
#  2380136: 'later',
#  2429618: 'legends',
#  399025: 'beginning',
#  3169908: 'poem',
#  3989855: 'statius',
#  674604: 'century',
#  48324: 'ad',
#  3981869: 'state',
#  2155413: 'invulnerable',
#  475746: 'body',
#  1172965: 'dipped',
#  3565277: 'river',
#  4055843: 'styx',
#  2087838: 'infant',
#  1915079: 'held',
#  1912537: 'heels',
#  130317: 'alluding',
#  4194600: 'term',
#  816370: 'come',
#  2664470: 'mean',
#  3171548: 'point',
#  4558132: 'weakness',
#  1406635: 'especially',
#  4042610: 'strong',
#  886120: 'constitution',
#  2477053: 'linear',
#  4130385: 'tablets',
#  300019: 'attest',
#  3102345: 'personal',
#  1639162: 'forms',
#  2284945: 'ki',
#  1027021: 'dative',
#  4356621: 'turned',
#  1539362: 'female',
#  1633841: 'form',
#  300032: 'attested',
#  300210: 'attica',
#  1646918: 'fourth',
#  381985: 'bc',
#  2037844: 'ig',
#  31736: 'achillia',
#  3998600: 'stele',
#  1854978: 'halicarnassus',
#  1760987: 'gladiator',
#  1555590: 'fighting',
#  139943: 'amazon',
#  152425: 'analyzed',
#  815019: 'combination',
#  1205104: 'distress',
#  3028946: 'pain',
#  3913822: 'sorrow',
#  1817802: 'grief',
#  3085817: 'people',
#  3894538: 'soldiers',
#  2854341: 'nation',
#  3503882: 'resulting',
#  3291774: 'proto',
#  3003712: 'os',
#  1205304: 'distressed',
#  4209626: 'theme',
#  3349613: 'raised',
#  2929580: 'numerous',
#  4253252: 'times',
#  1665603: 'frequently',
#  3581898: 'role',
#  2158512: 'ironic',
#  2254884: 'juxtaposition',
#  907157: 'conventional',
#  4477911: 'view',
#  1765465: 'glory',
#  4436034: 'usually',
#  1687769: 'furthermore',
#  887357: 'construed',
#  1815068: 'gregory',
#  2837053: 'nagy',
#  1612926: 'following',
#  2436364: 'leonard',
#  3033917: 'palmer',
#  921356: 'corps',
#  2825125: 'muster',
#  4281572: 'topical',
#  1392177: 'epitheta',
#  4119392: 'swift',
#  1619602: 'footedness',
#  1619587: 'footed',
#  1208086: 'divine',
#  3331648: 'quick',
#  3484664: 'researchers',
#  1074386: 'deem',
#  2496985: 'loan',
#  4627662: 'word',
#  3202546: 'possibly',
#  3221705: 'pre',
#  2369299: 'language',
#  3569781: 'robert',
#  394410: 'beekes',
#  4072067: 'suggested',
#  2995300: 'origin',
#  362405: 'based',
#  4215772: 'things',
#  796561: 'coexistence',
#  1384622: 'epic',
#  27517: 'account',
#  3033210: 'palatalized',
#  3119947: 'phoneme',
#  4083995: 'sup',
#  2996219: 'original',
#  3899562: 'son',
#  4694734: 'zeus',
#  3195438: 'poseidon',
#  3564971: 'rivals',
#  1860025: 'hand',
#  3275576: 'prometheus',
#  1628243: 'fore',
#  4218260: 'thinker',
#  4537971: 'warned',
#  3282477: 'prophecy',
#  2998667: 'originally',
#  4439121: 'uttered',
#  4210491: 'themis',
#  1770499: 'goddess',
#  2392594: 'law',
#  384579: 'bear',
#  1809725: 'greater',
#  3386838: 'reason',
#  1771771: 'gods',
#  4611019: 'withdrew',
#  3318185: 'pursuit',
#  4567129: 'wed',
#  4141065: 'tale',
#  2953532: 'offers',
#  136364: 'alternative',
#  4463750: 'version',
#  1421304: 'events',
#  224420: 'argonautica',
#  3845250: 'sister',
#  4589133: 'wife',
#  1932735: 'hera',
#  130253: 'alludes',
#  715506: 'chaste',
#  3489729: 'resistance',
#  67734: 'advances',
#  3174372: 'pointing',
#  2536484: 'loyal',
#  2622634: 'marriage',
#  484608: 'bond',
#  913949: 'coolly',
#  3436144: 'rejected',
#  1027076: 'daughter',
#  3695445: 'sea',
#  1768933: 'god',
#  2877910: 'nereus',
#  551536: 'brought',
#  1454680: 'explaining',
#  1686694: 'furious',
#  1072726: 'decreed',
#  2627064: 'marry',
#  25525: 'according',
#  31280: 'achilleid',
#  4657273: 'written',
#  2906993: 'non',
#  4108866: 'surviving',
#  3241728: 'previous',
#  497285: 'born',
#  4330674: 'tried',
#  2575963: 'make',
#  1173024: 'dipping',
#  2423523: 'left',
#  4513512: 'vulnerable',
#  4191751: 'tendon',
#  774938: 'clear',
#  2331774: 'known',
#  1284632: 'earlier',
#  4020828: 'story',
#  176748: 'anointed',
#  507277: 'boy',
#  142137: 'ambrosia',
#  571481: 'burn',
#  324328: 'away',
#  3057200: 'parts',
#  2136496: 'interrupted',
#  1153: 'abandoned',
#  3345859: 'rage',
#  2579136: 'makes',
#  3416281: 'reference',
#  1724736: 'general',
#  2155226: 'invulnerability',
#  900543: 'contrary',
#  2698937: 'mentions',
#  4649695: 'wounded',
#  488042: 'book',
#  3026777: 'paeonian',
#  277753: 'asteropaeus',
#  3081335: 'pelagon',
#  682235: 'challenged',
#  3669726: 'scamander',
#  647684: 'cast',
#  3929539: 'spears',
#  1807902: 'grazed',
#  1317862: 'elbow',
#  1249360: 'drawing',
#  3954434: 'spurt',
#  464010: 'blood',
#  1649245: 'fragmentary',
#  3170521: 'poems',
#  997280: 'cycle',
#  1115611: 'description',
#  999559: 'cypria',
#  2485450: 'little',
#  2438155: 'lesches',
#  3322823: 'pyrrha',
#  102004: 'aithiopis',
#  2042613: 'iliou',
#  3099690: 'persis',
#  221825: 'arctinus',
#  2728841: 'miletus',
#  4295075: 'trace',
#  1498035: 'famous',
#  4453136: 'vase',
#  3030811: 'paintings',
#  3233431: 'presenting',
#  644219: 'cases',
#  245433: 'arrows',
#  1959671: 'hit',
#  1382695: 'entrusted',
#  735340: 'chiron',
#  671833: 'centaur',
#  2799148: 'mount',
#  3081525: 'pelion',
#  3386715: 'reared',
#  1630574: 'foretold',
#  1509716: 'fate',
#  1694954: 'gain',
#  1157516: 'die',
#  4681070: 'young',
#  2487515: 'live',
#  2508712: 'long',
#  4392103: 'uneventful',
#  2452823: 'life',
#  2937097: 'obscurity',
#  739544: 'chose',
#  1066106: 'decided',
#  1816019: 'grew',
#  3122144: 'phthia',
#  837879: 'companion',
#  3069681: 'patroclus',
#  3203354: 'post',
#  1976068: 'homeric',
#  760669: 'claim',
#  2987200: 'order',
#  3628102: 'safe',
#  4467268: 'versions',
#  1943587: 'hid',
#  2588352: 'man',
#  939495: 'court',
#  2548478: 'lycomedes',
#  3863200: 'skyros',
#  1192803: 'disguised',
#  1749476: 'girl',
#  2490623: 'lives',
#  1030585: 'daughters',
#  3409505: 'red',
#  1851560: 'haired',
#  1087780: 'deidamia',
#  3360208: 'rapes',
#  1516674: 'fathers',
#  2876737: 'neoptolemus',
#  589601: 'called',
#  3322855: 'pyrrhus',
#  3201484: 'possible',
#  114579: 'alias',
#  2949816: 'odysseus',
#  2409916: 'learns',
#  3282898: 'prophet',
#  587405: 'calchas',
#  30412: 'achaeans',
#  4378044: 'unable',
#  617716: 'capture',
#  95677: 'aid',
#  1773521: 'goes',
#  1837795: 'guise',
#  3079373: 'peddler',
#  3728270: 'selling',
#  4621341: 'women',
#  786485: 'clothes',
#  2207185: 'jewelry',
#  3143342: 'places',
#  3789702: 'shield',
#  3929192: 'spear',
#  1785996: 'goods',
#  2117803: 'instantly',
#  4136157: 'takes',
#  3721583: 'sees',
#  1192183: 'disguise',
#  911370: 'convinces',
#  2223136: 'join',
#  604399: 'campaign',
#  238133: 'arranges',
#  4344829: 'trumpet',
#  105854: 'alarm',
#  3918041: 'sounded',
#  1594695: 'flee',
#  3037791: 'panic',
#  3229232: 'prepares',
#  1082663: 'defend',
#  1759310: 'giving',
#  2034780: 'identity',
#  242000: 'arrived',
#  3794819: 'ships',
#  637853: 'carrying',
#  208623: 'appointed',
#  2400393: 'leaders',
#  2398184: 'leader',
#  829948: 'commanding',
#  2695572: 'menesthius',
#  1415262: 'eudorus',
#  3081187: 'peisander',
#  3118574: 'phoenix',
#  108779: 'alcimedon',
#  1812034: 'greeks',
#  22463: 'accidentally',
#  4014360: 'stopped',
#  2831085: 'mysia',
#  3609717: 'ruled',
#  4178202: 'telephus',
#  372702: 'battle',
#  1717809: 'gave',
#  4649298: 'wound',
#  1901835: 'heal',
#  887834: 'consulted',
#  2984792: 'oracle',
#  3983369: 'stated',
#  3775827: 'shall',
#  1835691: 'guided',
#  224476: 'argos',
#  1902197: 'healed',
#  1835215: 'guide',
#  4511510: 'voyage',
#  3473560: 'reports',
#  1415953: 'euripides',
#  2523370: 'lost',
#  3155248: 'play',
#  4574080: 'went',
#  308456: 'aulis',
#  3238556: 'pretending',
#  397987: 'beggar',
#  259441: 'asked',
#  3423327: 'refused',
#  762268: 'claiming',
#  2671373: 'medical',
#  2330469: 'knowledge',
#  136601: 'alternatively',
#  2992381: 'orestes',
#  3358845: 'ransom',
#  1902567: 'healing',
#  3388065: 'reasoned',
#  2091560: 'inflicted',
#  9125: 'able',
#  3128322: 'pieces',
#  3690338: 'scraped',
#  3587381: 'romance',
#  4337678: 'troilus',
#  746312: 'chryseis',
#  1112481: 'described',
#  1732098: 'geoffrey',
#  716063: 'chaucer',
#  969300: 'criseyde',
#  4595135: 'william',
#  3775092: 'shakespeare',
#  962835: 'cressida',
#  2672239: 'medieval',
#  2146332: 'invention',
#  2387902: 'latin',
#  4079026: 'summary',
#  4311926: 'transmitted',
#  1416163: 'europe',
#  2964812: 'older',
#  28238: 'accounts',
#  3248037: 'prince',
#  4683706: 'youngest',
#  3243914: 'priam',
#  1912012: 'hecuba',
#  2431561: 'legitimate',
#  3907293: 'sons',
#  188401: 'apollo',
#  1122650: 'despite',
#  4684040: 'youth',
#  2571422: 'main',
#  1987743: 'horse',
#  1554383: 'fighter',
#  708640: 'chariot',
#  3282405: 'prophecies',
#  2478805: 'linked',
#  142585: 'ambushed',
#  293067: 'attempt',
#  4044935: 'struck',
#  390402: 'beauty',
#  3182698: 'polyxena',
#  3014047: 'overcome',
#  2546713: 'lust',
#  1173505: 'directed',
#  3770468: 'sexual',
#  299918: 'attentions',
#  2860642: 'nbsp',
#  3425082: 'refusing',
#  4677353: 'yield',
#  2118220: 'instead',
#  1062097: 'decapitated',
#  134687: 'altar',
#  2970082: 'omphalos',
#  4237999: 'thymbraios',
#  222060: 'ardent',
#  2533916: 'lovers',
#  1332507: 'embrace',
#  2834171: 'myth',
#  599650: 'came',
#  3512046: 'retribution',
#  3626785: 'sacrilege',
#  153963: 'ancient',
#  4655379: 'writers',
#  4321764: 'treated',
#  1392209: 'epitome',
#  1042364: 'dead',
#  726202: 'child',
#  2800536: 'mourned',
#  3044794: 'parents',
#  2489264: 'lived',
#  66625: 'adulthood',
#  4454130: 'vatican',
#  2834649: 'mythographer',
#  761322: 'claimed',
#  2149954: 'invincible',
#  2849988: 'narrative',
#  1074156: 'deeds',
#  4651810: 'wrath',
#  2477228: 'lines',
#  3372166: 'read',
#  769002: 'class',
#  4592651: 'wikitable',
#  3840212: 'sing',
#  28860: 'accursed',
#  1808010: 'great',
#  4070176: 'suffering',
#  944234: 'covers',
#  4569947: 'weeks',
#  1061490: 'decade',
#  1216407: 'does',
#  2849667: 'narrate',
#  400165: 'begins',
#  4610806: 'withdrawal',
#  1194401: 'dishonoured',
#  82339: 'agamemnon',
#  828876: 'commander',
#  30385: 'achaean',
#  1624926: 'forces',
#  4133869: 'taken',
#  4617979: 'woman',
#  2838499: 'named',
#  3866018: 'slave',
#  746329: 'chryses',
#  3245041: 'priest',
#  401966: 'begs',
#  3513357: 'return',
#  3424067: 'refuses',
#  3731483: 'sends',
#  3144334: 'plague',
#  923459: 'correctly',
#  1137596: 'determines',
#  3918622: 'source',
#  4340835: 'troubles',
#  3927301: 'speak',
#  4406110: 'unless',
#  4511200: 'vows',
#  3287698: 'protect',
#  1070944: 'declares',
#  3516441: 'returned',
#  877756: 'consents',
#  830362: 'commands',
#  3256963: 'prize',
#  538535: 'briseis',
#  538569: 'briseus',
#  3468416: 'replace',
#  165275: 'angry',
#  1194380: 'dishonour',
#  1888421: 'having',
#  3167557: 'plunder',
#  3666760: 'says',
#  2534251: 'loves',
#  4420183: 'urging',
#  1550961: 'fight',
#  2396961: 'lead',
#  4338863: 'troops',
#  131854: 'alongside',
#  4243869: 'time',
#  572276: 'burning',
#  4209032: 'theft',
#  3221664: 'prays',
#  909552: 'convince',
#  1921207: 'help',
#  4338106: 'trojans',
#  1821941: 'ground',
#  3425387: 'regain',
#  1979721: 'honour',
#  4359506: 'turns',
#  4206215: 'thanks',
#  2091745: 'influence',
#  2879424: 'nestor',
#  4603604: 'winning',
#  163800: 'angered',
#  4419959: 'urges',
#  207149: 'appease',
#  93466: 'agrees',
#  725918: 'chieftains',
#  102315: 'ajax',
#  2951354: 'offer',
#  1745450: 'gifts',
#  3436838: 'rejects',
#  3836711: 'simply',
#  3633937: 'sail',
#  1971878: 'home',
#  3150906: 'planning',
#  2419668: 'led',
#  4060306: 'subsequently',
#  3318707: 'push',
#  234461: 'army',
#  383140: 'beaches',
#  267450: 'assault',
#  4462024: 'verge',
#  13569: 'absolute',
#  1132126: 'destruction',
#  2402576: 'leads',
#  4563077: 'wearing',
#  233116: 'armour',
#  3454659: 'remains',
#  603668: 'camp',
#  4063889: 'succeeds',
#  3319492: 'pushing',
#  3281370: 'proper',
#  755974: 'city',
#  3396482: 'receiving',
#  2887189: 'news',
#  182108: 'antilochus',
#  1818246: 'grieves',
#  415240: 'beloved',
#  819094: 'comes',
#  821172: 'comfort',
#  1204805: 'distraught',
#  3106598: 'persuades',
#  1932599: 'hephaestus',
#  2881886: 'new',
#  3139717: 'place',
#  2072133: 'includes',
#  1373099: 'enraged',
#  1356986: 'ends',
#  3423055: 'refusal',
#  1548552: 'field',
#  2300195: 'killing',
#  2690822: 'men',
#  3716248: 'seeking',
#  1365859: 'engages',
#  737809: 'choking',
#  4549655: 'waters',
#  4331721: 'tries',
#  1262870: 'drown',
#  2914792: 'note',
#  3500652: 'restrain',
#  3625123: 'sack',
#  125646: 'allotted',
#  4394906: 'unhindered',
#  1086589: 'defy',
#  1570540: 'finally',
#  1574161: 'finds',
#  3243420: 'prey',
#  715051: 'chases',
#  4521367: 'wall',
#  280089: 'athena',
#  1518636: 'favorite',
#  1050952: 'dearest',
#  546677: 'brother',
#  1087964: 'deiphobus',
#  4012174: 'stop',
#  3614946: 'running',
#  1472434: 'face',
#  3381360: 'realizes',
#  4329010: 'trick',
#  2336895: 'knows',
#  2087128: 'inevitable',
#  4529241: 'wanting',
#  708088: 'charges',
#  4559415: 'weapon',
#  4121327: 'sword',
#  2748203: 'misses',
#  19477: 'accepting',
#  3925160: 'spare',
#  4321549: 'treat',
#  3492166: 'respect',
#  4183661: 'tells',
#  1983379: 'hopeless',
#  1447522: 'expect',
#  1071229: 'declaring',
#  1688091: 'fury',
#  1257880: 'drive',
#  1847725: 'hack',
#  1596896: 'flesh',
#  1297213: 'eat',
#  3366396: 'raw',
#  91584: 'agonies',
#  660948: 'caused',
#  2302904: 'kills',
#  1245967: 'drags',
#  922325: 'corpse',
#  1251694: 'dream',
#  1965045: 'hold',
#  1684940: 'funeral',
#  1993599: 'hosts',
#  3746294: 'series',
#  1704525: 'games',
#  271566: 'assistance',
#  1935275: 'hermes',
#  4193246: 'tent',
#  3163398: 'plead',
#  570627: 'buried',
#  3448631: 'relents',
#  3277415: 'promises',
#  4342185: 'truce',
#  1275481: 'duration',
#  1231333: 'doom',
#  75449: 'aethiopis',
#  4630401: 'work',
#  3204400: 'posthomerica',
#  848999: 'composed',
#  3335634: 'quintus',
#  3882505: 'smyrna',
#  3437896: 'relate',
#  3085630: 'penthesilea',
#  3326433: 'queen',
#  140272: 'amazons',
#  223720: 'ares',
#  242891: 'arrives',
#  1983472: 'hopes',
#  1076225: 'defeat',
#  4190167: 'temporary',
#  1557307: 'fights',
#  1818188: 'grieve',
#  1204275: 'distracted',
#  1154092: 'did',
#  2128992: 'intensely',
#  4435691: 'usual',
#  3380637: 'realized',
#  1204564: 'distraction',
#  1353670: 'endangering',
#  3421670: 'refocused',
#  785637: 'closest',
#  2688220: 'memnon',
#  1034479: 'dawn',
#  1384407: 'eos',
#  1414420: 'ethiopia',
#  3867723: 'slays',
#  2940014: 'obtains',
#  3533438: 'revenge',
#  377554: 'battlefield',
#  878221: 'consequently',
#  2439360: 'let',
#  4081361: 'sun',
#  3561080: 'rise',
#  1299689: 'echoes',
#  4406515: 'unlike',
#  3679527: 'scholars',
#  224907: 'argued',
#  1385355: 'episode',
#  2115305: 'inspired',
#  1133961: 'details',
#  3371278: 'reaction',
#  1638130: 'formed',
#  366297: 'basis',
#  997609: 'cyclic',
#  3673520: 'scattered',
#  1649294: 'fragments',
#  3337944: 'quoted',
#  313258: 'authors',
#  1433005: 'exact',
#  2857054: 'nature',
#  3439475: 'relationship',
#  4057234: 'subject',
#  1200436: 'dispute',
#  770645: 'classical',
#  3095541: 'period',
#  2761667: 'modern',
#  203166: 'appears',
#  2760233: 'model',
#  1074720: 'deep',
#  1674440: 'friendship',
#  4071755: 'suggest',
#  783119: 'close',
#  1667838: 'friend',
#  1173151: 'direct',
#  1427410: 'evidence',
#  4204055: 'text',
#  4211502: 'theory',
#  1461917: 'expressed',
#  4628830: 'words',
#  1203733: 'distinguish',
#  1942344: 'heterosexual',
#  1977262: 'homosexual',
#  275820: 'assumed',
#  1119901: 'desire',
#  1866068: 'handsome',
#  3769266: 'sex',
#  3224062: 'predicted',
#  1281016: 'dying',
#  526122: 'breath',
#  3509636: 'retellings',
#  3669421: 'scaling',
#  3175728: 'poisoned',
#  1101798: 'deny',
#  3914244: 'sort',
#  4444443: 'valour',
#  3019798: 'owing',
#  834900: 'common',
#  854202: 'conception',
#  945027: 'coward',
#  3453026: 'remained',
#  4385641: 'undefeated',
#  486730: 'bones',
#  2737798: 'mingled',
#  3474740: 'represented',
#  2492518: 'living',
#  2161769: 'island',
#  2443351: 'leuke',
#  2801503: 'mouth',
#  1015994: 'danube',
#  1536198: 'fell',
#  1075567: 'deeply',
#  2528194: 'love',
#  3250279: 'princesses',
#  261608: 'asks',
#  4596584: 'willing',
#  123072: 'alliance',
#  4640218: 'world',
#  3017099: 'overseeing',
#  3256185: 'private',
#  1916265: 'helen',
#  2624359: 'married',
#  1945490: 'hides',
#  575221: 'bushes',
#  3801412: 'shoots',
#  2950324: 'odyssey',
#  2096297: 'informs',
#  3182956: 'pompous',
#  570522: 'burial',
#  1396661: 'erection',
#  2799083: 'mound',
#  1919519: 'hellespont',
#  4077549: 'suitors',
#  1848409: 'hades',
#  763085: 'claims',
#  563641: 'built',
#  2639977: 'massive',
#  382710: 'beach',
#  2042594: 'ilion',
#  3718025: 'seen',
#  211712: 'approaching',
#  2945059: 'ocean',
#  962572: 'cremated',
#  256709: 'ashes',
#  4420788: 'urn',
#  3117197: 'philoctetes',
#  4432441: 'using',
#  1372808: 'enormous',
#  504987: 'bow',
#  1932926: 'heracles',
#  3634506: 'sails',
#  4390318: 'underworld',
#  908363: 'converses',
#  3772324: 'shades',
#  1814003: 'greeted',
#  459160: 'blessed',
#  3494492: 'responds',
#  4648013: 'worst',
#  2642884: 'masters',
#  1457804: 'exploits',
#  1939842: 'heroic',
#  38405: 'actions',
#  1562033: 'filled',
#  3653781: 'satisfaction',
#  2414372: 'leaves',
#  3372884: 'reader',
#  141367: 'ambiguous',
#  4388667: 'understanding',
#  1538200: 'felt',
#  2670356: 'medea',
#  1057184: 'deaths',
#  4398881: 'united',
#  1330534: 'elysian',
#  1549574: 'fields',
#  3277004: 'promised',
#  188831: 'apollonius',
#  2934725: 'object',
#  1544572: 'feud',
#  4176392: 'telamonian',
#  843145: 'competed',
#  3935812: 'speeches',
#  521066: 'bravest',
#  3255485: 'prisoners',
#  880748: 'considering',
#  1116756: 'deserving',
#  990660: 'cursed',
#  1287919: 'earned',
#  2156761: 'ire',
#  4189463: 'temporarily',
#  2557193: 'mad',
#  166312: 'anguish',
#  396230: 'began',
#  3785963: 'sheep',
#  4218456: 'thinking',
#  851751: 'comrades',
#  2459507: 'lifted',
#  2559465: 'madness',
#  46100: 'actually',
#  256294: 'ashamed',
#  834148: 'committed',
#  4074784: 'suicide',
#  1423181: 'eventually',
#  3448963: 'relic',
#  544812: 'bronze',
#  1899196: 'headed',
#  674103: 'centuries',
#  3234299: 'preserved',
#  4188410: 'temple',
#  34755: 'acropolis',
#  3114463: 'phaselis',
#  2548452: 'lycia',
#  3189145: 'port',
#  3035649: 'pamphylian',
#  1838535: 'gulf',
#  4496163: 'visited',
#  111988: 'alexander',
#  1383818: 'envisioned',
#  635687: 'carried',
#  440132: 'biographers',
#  2696757: 'mention',
#  3811701: 'shown',
#  3073651: 'pausanias',
#  3206637: 'pottery',
#  2697252: 'mentioned',
#  2484586: 'literary',
#  4300373: 'traditions',
#  3161256: 'playing',
#  470964: 'board',
#  1701133: 'game',
#  3112253: 'petteia',
#  14176: 'absorbed',
#  2936575: 'oblivious',
#  4105930: 'surrounding',
#  288160: 'attacked',
#  3370053: 'reached',
#  1937858: 'heroes',
#  3658730: 'saved',
#  2138062: 'intervention',
#  4273634: 'tomb',
#  1463010: 'extant',
#  182570: 'antiquity',
#  4337516: 'troad',
#  4458339: 'venerated',
#  4213178: 'thessalians',
#  3099566: 'persian',
#  1448557: 'expeditionary',
#  3586701: 'roman',
#  1339058: 'emperor',
#  622906: 'caracalla',
#  984478: 'cult',
#  279007: 'astypalaea',
#  3949795: 'sporades',
#  3926429: 'sparta',
#  3644132: 'sanctuary',
#  1325185: 'elis',
#  1975246: 'homeland',
#  4213190: 'thessaly',
#  2566618: 'magna',
#  1797809: 'graecia',
#  754797: 'cities',
#  4153193: 'tarentum',
#  2502867: 'locri',
#  975719: 'croton',
#  28201: 'accounting',
#  3037777: 'panhellenic',
#  3952193: 'spread',
#  2129121: 'intensity',
#  4458372: 'veneration',
#  3765759: 'settled',
#  2911961: 'northern',
#  792100: 'coast',
#  3183492: 'pontus',
#  1417511: 'euxinus',
#  4266193: 'today',
#  448237: 'black',
#  3456353: 'remarkable',
#  219071: 'archaic',
#  2728791: 'milesian',
#  808246: 'colony',
#  2962072: 'olbia',
#  2722958: 'middle',
#  2033407: 'identified',
#  3882840: 'snake',
#  4373319: 'ukrainian',
#  4696468: 'zmiinyi',
#  2290395: 'kiliya',
#  4373256: 'ukraine',
#  1286090: 'early',
#  1073484: 'dedicatory',
#  2110632: 'inscriptions',
#  807948: 'colonies',
#  1797911: 'graffiti',
#  2110504: 'inscribed',
#  773210: 'clay',
#  1194969: 'disks',
#  4510782: 'votive',
#  2953480: 'offerings',
#  222197: 'area',
#  422034: 'berezan',
#  4159046: 'tauric',
#  721023: 'chersonese',
#  1444057: 'existence',
#  3852240: 'sixth',
#  2972645: 'onwards',
#  4231494: 'thriving',
#  3998598: 'stelae',
#  3415897: 'refer',
#  3600602: 'roughly',
#  2517785: 'lord',
#  2151708: 'invoked',
#  3290418: 'protector',
#  3040952: 'par',
#  2968204: 'olympian',
#  2497948: 'local',
#  3285812: 'prostates',
#  91726: 'agoraeus',
#  3165030: 'pliny',
#  1318005: 'elder',
#  2856335: 'natural',
#  1957888: 'history',
#  3195077: 'portus',
#  30474: 'achaeorum',
#  2123594: 'insula',
#  31738: 'achillis',
#  4352815: 'tumulo',
#  1315788: 'eius',
#  4491267: 'viri',
#  766422: 'clara',
#  3850302: 'situated',
#  3898701: 'somewhat',
#  2863464: 'nearby',
#  1211475: 'dnieper',
#  560666: 'bug',
#  1412259: 'estuary',
#  2728230: 'miles',
#  3084219: 'peninsula',
#  4037763: 'stretches',
#  1641186: 'forth',
#  ...}

# %%
print(name_to_article)

# %%
# gensim
from gensim import corpora, models, similarities, matutils
# sklearn
from sklearn import datasets
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.cluster import KMeans



count_vectorizer = CountVectorizer(ngram_range=(1, 2), stop_words='english', token_pattern="\\b[a-z][a-z]+\\b")
count_vectorizer.fit(ng_train.data)

# %%
model = gensim.models.doc2vec.Doc2Vec(vector_size=300, window=10, epochs=50)
model.build_vocab(train_corpus)

# %%
# %time model.train(train_corpus, total_examples=model.corpus_count, epochs=50)

# %%
model.docvecs.most_similar('Zuko')
# Out:
# [('Iroh', 0.42297089099884033),
#  ('Aang', 0.4034014344215393),
#  ('Korra', 0.4025777280330658),
#  ('Katara (Avatar: The Last Airbender)', 0.40019285678863525),
#  ('Azula', 0.3617665767669678),
#  ('Raksha (The Jungle Book)', 0.35100889205932617),
#  ('Zaheer (The Legend of Korra)', 0.34087809920310974),
#  ('Toph Beifong', 0.33944350481033325),
#  ('Sokka', 0.3380088806152344),
#  ('Tenzin (The Legend of Korra)', 0.32860681414604187)]

# %%
model.docvecs.most_similar('Aang')
# Out:
# [('Zuko', 0.4034014344215393),
#  ('Katara (Avatar: The Last Airbender)', 0.39002037048339844),
#  ('Korra', 0.35815495252609253),
#  ('Zaheer (The Legend of Korra)', 0.3445892333984375),
#  ('Tenzin (The Legend of Korra)', 0.33562031388282776),
#  ('Sokka', 0.3217317461967468),
#  ('Iroh', 0.3168046474456787),
#  ('Bran Stark', 0.2853764295578003),
#  ('Azula', 0.269309937953949),
#  ('Johnny Smith (Dead Zone)', 0.2681092619895935)]

# %%
model.docvecs.most_similar('Professor Farnsworth')
# Out:
# [('Zoidberg', 0.31845948100090027),
#  ('Gipsy Danger', 0.31159722805023193),
#  ('Charlie Frost', 0.30390626192092896),
#  ('Professor Bobo', 0.29978621006011963),
#  ('Dick Solomon', 0.29420942068099976),
#  ('Zapp Brannigan', 0.28526467084884644),
#  ('Tom Paris', 0.285208523273468),
#  ('Professor Hershel Layton', 0.2830590605735779),
#  ('Thomas J. Whitmore', 0.2812904715538025),
#  ('Kryten', 0.27740347385406494)]

# %%
def find_most_similar(word_list):
    inferred_vector = model.infer_vector(word_list)
#     print(len(inferred_vector))
    sims = model.docvecs.most_similar([inferred_vector], topn=10)
    return sims

# %%
word_list = to_word_list(name_to_article['Bender (Futurama)'])
find_most_similar(word_list)
# Out:
# [('Bender (Futurama)', 0.9172766208648682),
#  ('Burt Gummer', 0.6373168230056763),
#  ('Sammy the Shunter', 0.6062910556793213),
#  ('The Smurfs (comics)', 0.5927327275276184),
#  ('Karla (character)', 0.5844019055366516),
#  ('Nick Carter-Killmaster', 0.5783843398094177),
#  ('Mega Mindy', 0.5779253840446472),
#  ('Yig', 0.5778729915618896),
#  ('Jerom', 0.5753814578056335),
#  ('Pluk van de Petteflet', 0.5753750801086426)]

# %%
for doc in train_corpus_docs:
    page_name = doc.tags[0]
    inferred_vector = model.infer_vector(train_corpus[page_name].words)
    sims = model.docvecs.most_similar([inferred_vector], topn=5
    print('Character:', page_name, 'Most Similar:'
    rank = [docid for docid, sim in sims].index(page_name)
    print(rank)
    break
# Out:
# 0
